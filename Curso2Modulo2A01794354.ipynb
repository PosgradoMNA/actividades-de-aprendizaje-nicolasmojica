# %%
#Limpieza de informacion
#Instalacion de las librerias que se necesitan para el proceso

# %%
import pandas as pd
import matplotlib.pylab as plt

# %%
# Para poder reemplazar los valores es necesario realizarlo con: df.replace("?", np.nan, inplace = True)

# %%
# Para determinar el tipo de formato que se tiene dentro del proceso: df.dtypes

# %%
#Para generar calculos con las columnas de los data frames. df['city-L/100km'] = 235/df["city-mpg"]

# %%
# Ahora opara generar calculos tambien tenemos df['length'] = df['length']/df['length'].max()
#df['width'] = df['width']/df['width'].max()

# %% [markdown]
# ![Captura de Pantalla 2022-10-18 a la(s) 20.02.28.png](data:image/png;base64,...)
