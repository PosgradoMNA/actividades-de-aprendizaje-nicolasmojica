# %% [markdown]
# Curso: Análisis de datoa con Python
# Modulo 1
#
# Nombre: Nicolas Mojica Gomez
# Matricula: A01794354

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Usamos la función pandas.read_csv() para leer el archivo csv. Entre paréntesis, ponemos la ruta del archivo junto con una comilla para que los pandas lean el archivo en un marco de datos desde esa dirección. La ruta del archivo puede ser una URL o la dirección de su archivo local.
# Debido a que los datos no incluyen encabezados, podemos agregar un argumento headers = None dentro del método read_csv() para que pandas no establezca automáticamente la primera fila como encabezado.
#
# También puede asignar el conjunto de datos a cualquier variable que cree.

# %% [markdown]
# Agregar encabezados
# Pandas establece automáticamente el encabezado con un número entero a partir de 0.
#
# Por lo tanto, tenemos que agregar encabezados manualmente.

# %% [markdown]
# Guardar conjunto de datos
# En consecuencia, Pandas nos permite guardar el conjunto de datos en csv. Al usar el método dataframe.to_csv(), puede agregar la ruta y el nombre del archivo junto con comillas entre corchetes.
#
# Por ejemplo, si desea guardar el marco de datos df como automóvil.csv en su máquina local, puede usar la siguiente sintaxis, donde índice = Falso significa que los nombres de las filas no se escribirán.

# %% [markdown]
# Usamos la función pandas.read_csv() para leer el archivo csv. Entre paréntesis, ponemos la ruta del archivo junto con una comilla para que los pandas lean el archivo en un marco de datos desde esa dirección. La ruta del archivo puede ser una URL o la dirección de su archivo local.
# Debido a que los datos no incluyen encabezados, podemos agregar un argumento headers = None dentro del método read_csv() para que pandas no establezca automáticamente la primera fila como encabezado.
#
# También puede asignar el conjunto de datos a cualquier variable que cree.

# %% [markdown]
# ![Captura de pantalla 2022-10-09 131612.png](data:image/png;base64,...)
